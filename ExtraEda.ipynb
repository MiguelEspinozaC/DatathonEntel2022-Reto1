# %%
## Archivo de Entrenamiento
! gdown 1xdn0ExmhhlN4OVSBrIqR1sB-iQ4xJCOD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xdn0ExmhhlN4OVSBrIqR1sB-iQ4xJCOD
# To: /content/dfTrainV_20220814.csv
# 100% 358M/358M [00:01<00:00, 261MB/s]

# %%
## Archivo de Submit
! gdown  1ax6A09uCA26G2mmykWj4Atdp-DhwhSxf
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ax6A09uCA26G2mmykWj4Atdp-DhwhSxf
# To: /content/dfSubmitV_20220814.csv
# 100% 122M/122M [00:00<00:00, 293MB/s]

# %%
# Pandas
import pandas as pd


# SKLearn
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, accuracy_score, recall_score

# MatplotLib
from matplotlib import pyplot as plt

# Seaborn
import seaborn as sns

# Numpy
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
dfTrain  = pd.read_csv('/content/dfTrainV_20220814.csv' )
dfSubmit = pd.read_csv('/content/dfSubmitV_20220814.csv' )

# %%
cat_features = ["TIPO_ADQ","SCORECAT","MARCA","MODELO","NUEVA_GAMMA","OS","DEVICE_TYPE",
                "GIRO","SUBGIRO",
                "TIENE_PROD_1","TIENE_PROD_2","TIENE_PROD_3",
                "FLG_GRUPO1","FLG_GRUPO2","FLG_GRUPO3","FLG_GRUPO4","FLG_GRUPO5",
                "FLG_GRUPO6","FLG_GRUPO7","FLG_GRUPO8","FLG_GRUPO9","FLG_GRUPO10",
                "FLG_GRUPO11",
                "FLG_TARGETPREV","TIPOEQUIPO" , 
                "apptoppreferida" , "flgusopreferente" , "flg_flujo"]

# %%
data   = dfTrain.drop(['nro_telefono_hash','TARGET'], axis=1)
data[cat_features] = data[cat_features].astype(str)
target = dfTrain['TARGET']

# %%
#Checking the final output
print(data['FLG_GRUPO1'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO1'].value_counts(normalize=True)*100)
# Out:
# 0    62.680581
# 1    37.319419
# Name: FLG_GRUPO1, dtype: float64
# ------------------------
# 0    63.90707
# 1    36.09293
# Name: FLG_GRUPO1, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO2'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO2'].value_counts(normalize=True)*100)
# Out:
# 0    98.919625
# 1     1.080375
# Name: FLG_GRUPO2, dtype: float64
# ------------------------
# 0    98.937009
# 1     1.062991
# Name: FLG_GRUPO2, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO3'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO3'].value_counts(normalize=True)*100)
# Out:
# 0    100.0
# Name: FLG_GRUPO3, dtype: float64
# ------------------------
# 0    96.004803
# 1     3.995197
# Name: FLG_GRUPO3, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO4'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO4'].value_counts(normalize=True)*100)
# Out:
# 0    85.641562
# 1    14.358438
# Name: FLG_GRUPO4, dtype: float64
# ------------------------
# 0    86.122681
# 1    13.877319
# Name: FLG_GRUPO4, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO5'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO5'].value_counts(normalize=True)*100)
# Out:
# 0    100.0
# Name: FLG_GRUPO5, dtype: float64
# ------------------------
# 0    84.82061
# 1    15.17939
# Name: FLG_GRUPO5, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO6'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO6'].value_counts(normalize=True)*100)
# Out:
# 0    67.240963
# 1    32.759037
# Name: FLG_GRUPO6, dtype: float64
# ------------------------
# 0    65.462157
# 1    34.537843
# Name: FLG_GRUPO6, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO7'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO7'].value_counts(normalize=True)*100)
# Out:
# 0    87.373236
# 1    12.626764
# Name: FLG_GRUPO7, dtype: float64
# ------------------------
# 0    85.138489
# 1    14.861511
# Name: FLG_GRUPO7, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO8'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO8'].value_counts(normalize=True)*100)
# Out:
# 1    84.34189
# 0    15.65811
# Name: FLG_GRUPO8, dtype: float64
# ------------------------
# 1    83.528188
# 0    16.471812
# Name: FLG_GRUPO8, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO9'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO9'].value_counts(normalize=True)*100)
# Out:
# 0    81.016563
# 1    18.983437
# Name: FLG_GRUPO9, dtype: float64
# ------------------------
# 0    78.389056
# 1    21.610944
# Name: FLG_GRUPO9, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO10'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO10'].value_counts(normalize=True)*100)
# Out:
# 0    63.872984
# 1    36.127016
# Name: FLG_GRUPO10, dtype: float64
# ------------------------
# 0    63.936553
# 1    36.063447
# Name: FLG_GRUPO10, dtype: float64

# %%
#Checking the final output
print(data['FLG_GRUPO11'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_GRUPO11'].value_counts(normalize=True)*100)
# Out:
# 0    88.537815
# 1    11.462185
# Name: FLG_GRUPO11, dtype: float64
# ------------------------
# 0    86.811508
# 1    13.188492
# Name: FLG_GRUPO11, dtype: float64

# %%
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO1'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO2'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO3'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO4'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO6'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO7'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO8'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO9'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO10'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO5"] == 1]['FLG_GRUPO11'].value_counts(normalize=True)*100)
print("----------------")
# Out:
# 1    50.178338
# 0    49.821662
# Name: FLG_GRUPO1, dtype: float64
# ----------------
# 0    98.396723
# 1     1.603277
# Name: FLG_GRUPO2, dtype: float64
# ----------------
# 0    92.799378
# 1     7.200622
# Name: FLG_GRUPO3, dtype: float64
# ----------------
# 0    76.198044
# 1    23.801956
# Name: FLG_GRUPO4, dtype: float64
# ----------------
# 1    52.759826
# 0    47.240174
# Name: FLG_GRUPO6, dtype: float64
# ----------------
# 0    77.264541
# 1    22.735459
# Name: FLG_GRUPO7, dtype: float64
# ----------------
# 1    99.996469
# 0     0.003531
# Name: FLG_GRUPO8, dtype: float64
# ----------------
# 0    67.182258
# 1    32.817742
# Name: FLG_GRUPO9, dtype: float64
# ----------------
# 1    55.235371
# 0    44.764629
# Name: FLG_GRUPO10, dtype: float64
# ----------------
# 0    79.630611
# 1    20.369389
# Name: FLG_GRUPO11, dtype: float64
# ----------------

# %%
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO1'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO2'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO4'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO6'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO7'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO8'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO9'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO10'].value_counts(normalize=True)*100)
print("----------------")
print(dfSubmit[dfSubmit["FLG_GRUPO3"] == 1]['FLG_GRUPO11'].value_counts(normalize=True)*100)
print("----------------")
# Out:
# 1    65.879512
# 0    34.120488
# Name: FLG_GRUPO1, dtype: float64
# ----------------
# 0    97.182343
# 1     2.817657
# Name: FLG_GRUPO2, dtype: float64
# ----------------
# 0    61.626191
# 1    38.373809
# Name: FLG_GRUPO4, dtype: float64
# ----------------
# 1    67.932376
# 0    32.067624
# Name: FLG_GRUPO6, dtype: float64
# ----------------
# 0    61.585939
# 1    38.414061
# Name: FLG_GRUPO7, dtype: float64
# ----------------
# 1    100.0
# Name: FLG_GRUPO8, dtype: float64
# ----------------
# 0    62.538575
# 1    37.461425
# Name: FLG_GRUPO9, dtype: float64
# ----------------
# 1    64.497518
# 0    35.502482
# Name: FLG_GRUPO10, dtype: float64
# ----------------
# 0    77.794177
# 1    22.205823
# Name: FLG_GRUPO11, dtype: float64
# ----------------

# %%
#Checking the final output
print(data['FLG_TARGETPREV'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['FLG_TARGETPREV'].value_counts(normalize=True)*100)
# Out:
# NO_TARGET         60.373939
# NO_INFORMACION    37.647266
# SI_TARGET          1.978795
# Name: FLG_TARGETPREV, dtype: float64
# ------------------------
# NO_TARGET         91.326676
# NO_INFORMACION     5.664463
# SI_TARGET          3.008861
# Name: FLG_TARGETPREV, dtype: float64

# %%
#Checking the final output
print(data['TIPOEQUIPO'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['TIPOEQUIPO'].value_counts(normalize=True)*100)
# Out:
# PROPIO        82.721878
# FINANCIADO    17.278122
# Name: TIPOEQUIPO, dtype: float64
# ------------------------
# PROPIO        82.587417
# FINANCIADO    17.412583
# Name: TIPOEQUIPO, dtype: float64

# %%
#Checking the final output
print(data['apptoppreferida'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['apptoppreferida'].value_counts(normalize=True)*100)
# Out:
# trafico_app_2    56.744745
# ninguna          17.893178
# trafico_app_8    13.625131
# trafico_app_1     9.411267
# trafico_app_3     1.615070
# trafico_app_9     0.385142
# trafico_app_7     0.295446
# trafico_app_6     0.023614
# trafico_app_4     0.005309
# trafico_app_5     0.001098
# Name: apptoppreferida, dtype: float64
# ------------------------
# trafico_app_2    57.849144
# ninguna          18.258474
# trafico_app_8    13.204038
# trafico_app_1     8.329179
# trafico_app_3     1.494514
# trafico_app_9     0.535516
# trafico_app_7     0.295365
# trafico_app_6     0.027875
# trafico_app_4     0.004288
# trafico_app_5     0.001608
# Name: apptoppreferida, dtype: float64

# %%
#Checking the final output
print(data['flgusopreferente'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['flgusopreferente'].value_counts(normalize=True)*100)
# Out:
# usoresto        90.887474
# usopreferido     9.112526
# Name: flgusopreferente, dtype: float64
# ------------------------
# usoresto        91.989236
# usopreferido     8.010764
# Name: flgusopreferente, dtype: float64

# %%
#Checking the final output
print(data['flg_flujo'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['flg_flujo'].value_counts(normalize=True)*100)
# Out:
# conflg_03    27.564563
# conflg_02    21.967007
# conflg_04    21.376846
# conflg_06    12.008779
# conflg_05     8.951440
# conflg_01     8.131366
# Name: flg_flujo, dtype: float64
# ------------------------
# conflg_03    27.135498
# conflg_02    22.282081
# conflg_04    20.956424
# conflg_06    12.280420
# conflg_05     8.848614
# conflg_01     8.496963
# Name: flg_flujo, dtype: float64

# %%
#Checking the final output
print(data['TIPO_ADQ'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['TIPO_ADQ'].value_counts(normalize=True)*100)
# Out:
# tipo1    54.334129
# tipo2    45.665871
# Name: TIPO_ADQ, dtype: float64
# ------------------------
# tipo1    52.891734
# tipo2    47.108266
# Name: TIPO_ADQ, dtype: float64

# %%
#Checking the final output
print(data['SCORECAT'].value_counts(normalize=True)*100)
print("------------------------")
#Checking the final output
print(dfSubmit['SCORECAT'].value_counts(normalize=True)*100)
# Out:
# medio            38.646365
# muy alto         20.695709
# NOINFORMACION    15.648957
# alto             14.562908
# bajo             10.446062
# Name: SCORECAT, dtype: float64
# ------------------------
# medio            40.416191
# muy alto         17.109714
# NOINFORMACION    16.461627
# alto             14.287399
# bajo             11.725070
# Name: SCORECAT, dtype: float64

# %%
from IPython.display import display_html
from itertools import chain,cycle
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %%
mm = data['MARCA'].value_counts(normalize=True)*100
mm = mm.rename_axis('unique_values').reset_index(name='counts')

nn = dfSubmit['MARCA'].value_counts(normalize=True)*100
nn = nn.rename_axis('unique_values').reset_index(name='counts')

# %%
display_side_by_side(mm.head(10) , nn.head(10) , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique_values</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2a1022b922f5038bc5bff79ff2960cd12cf266647b4f59121997a75c710b5b5d</td>
#       <td>25.423583</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>dc937b59892604f5a86ac96936cd7ff09e25f18ae6b758e8014a24c7fa039e91</td>
#       <td>13.347990</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>55562347f437d65829303cf6307e71acf8b84a020989dd218f31586eeafd01a9</td>
#       <td>11.275289</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>f01640a07b4c0521a49c0ec0a8915832798f19533aecdacb7dba51d8aeb2bbc5</td>
#       <td>11.269614</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
## dc937b59892604f5a86ac96936cd7ff09e25f18ae6b758e8014a24c7fa039e91

# %%
mm = data['GIRO'].value_counts(normalize=True)*100
mm = mm.rename_axis('GIRO').reset_index(name='counts')

nn = dfSubmit['GIRO'].value_counts(normalize=True)*100
nn = nn.rename_axis('GIRO').reset_index(name='counts')

# %%
display_side_by_side(mm , nn , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>GIRO</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5b8e595b8cebb006e39a3d289e465a5718996785008cbb70d94adceefcb56ca4</td>
#       <td>48.620884</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a9d0bcb92394bd06ed0e020135054d2dbf3e512fdf0b7f3c0111c419a768f72e</td>
#       <td>16.618036</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>404a18af35694f85854d87b70591b07c315b4ce5f5c7cfa58441b885be3927d2</td>
#       <td>10.370644</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>a830ede4aca0e9472dac4a9ba2f46bdca11aedc81fb2bcfe357daa27e43bad7d</td>
#       <td>4.980121</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
mm = data['SUBGIRO'].value_counts(normalize=True)*100
mm = mm.rename_axis('SUBGIRO').reset_index(name='counts')

nn = dfSubmit['SUBGIRO'].value_counts(normalize=True)*100
nn = nn.rename_axis('SUBGIRO').reset_index(name='counts')

display_side_by_side(mm.head(10) , nn.head(10)  , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SUBGIRO</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bd1b475ded03bdb3ab78de2f74782ad855c3c4b085d1675c18e114a76d965567</td>
#       <td>48.799360</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>e159ded5abcf126e18b05856319e4a4ee58a3267f298fdbaf864b7a1539b2b5f</td>
#       <td>5.640024</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>69513c48120d03eeaa1d4415e8da33a8026e9c56b80ba2965c2d3ee82eae4696</td>
#       <td>4.442496</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8e0b81ed56b34766254d0492d32fa9d5d08a33690db2b6aa6880f0879fac123b</td>
#       <td>2.967644</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %%
mm = data['NUEVA_GAMMA'].value_counts(normalize=True)*100
mm = mm.rename_axis('NUEVA_GAMMA').reset_index(name='counts')

nn = dfSubmit['NUEVA_GAMMA'].value_counts(normalize=True)*100
nn = nn.rename_axis('NUEVA_GAMMA').reset_index(name='counts')

display_side_by_side(mm.head(10) , nn.head(10) , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>NUEVA_GAMMA</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>dc937b59892604f5a86ac96936cd7ff09e25f18ae6b758e8014a24c7fa039e91</td>
#       <td>58.694068</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>76df0c6db32d4e04e0ef6a3a6a1e1686677e34308d9435892b1ab5713e57d470</td>
#       <td>15.763914</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NOINFORMACION</td>
#       <td>10.254223</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c4ebc6d4a5832cd9415f906ad03661110c705a72381c8b8b145761d02e2dd23a</td>
#       <td>6.112299</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>f793de205ead5ac302c4a1627829dea41f176b1068b993a32373fc869918374b</td>
# ...

# %%
mm = data['OS'].value_counts(normalize=True)*100
mm = mm.rename_axis('OS').reset_index(name='counts')

nn = dfSubmit['OS'].value_counts(normalize=True)*100
nn = nn.rename_axis('OS').reset_index(name='counts')

display_side_by_side(mm.head(10) , nn.head(10) , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>OS</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>fb8e9c929bbc4ccaebcf8d68296c419464bdfaf01a69708a4d01a0d3159f3116</td>
#       <td>63.679497</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>dc937b59892604f5a86ac96936cd7ff09e25f18ae6b758e8014a24c7fa039e91</td>
#       <td>13.347990</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1bde98c0df50d2e6aa7f88be84a65da1c7d6a285626385ff4ba22708d137ee77</td>
#       <td>11.242339</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NOINFORMACION</td>
#       <td>10.254223</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>c627c09c14e58e44bc51622dac392958ec88244e414b508020634f53cfcd1e69</td>
# ...

# %%
mm = data['DEVICE_TYPE'].value_counts(normalize=True)*100
mm = mm.rename_axis('DEVICE_TYPE').reset_index(name='counts')

nn = dfSubmit['DEVICE_TYPE'].value_counts(normalize=True)*100
nn = nn.rename_axis('DEVICE_TYPE').reset_index(name='counts')

display_side_by_side(mm , nn , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DEVICE_TYPE</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>SMARTPHONE</td>
#       <td>74.888704</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nan</td>
#       <td>13.347990</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NOINFORMACION</td>
#       <td>10.254223</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>MOBILE PHONE/FEATURE PHONE</td>
#       <td>0.758752</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>HANDHELD</td>
#       <td>0.280070</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>TABLET</td>
#       <td>0.171337</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>WLAN ROUTER</td>
#       <td>0.128320</td>
# ...

# %%
mm = data['MODELO'].value_counts(normalize=True)*100
mm = mm.rename_axis('MODELO').reset_index(name='counts')

nn = dfSubmit['MODELO'].value_counts(normalize=True)*100
nn = nn.rename_axis('MODELO').reset_index(name='counts')

display_side_by_side(mm.head(10) , nn.head(10)  , titles=['Train','Submit'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Train</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MODELO</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>dc937b59892604f5a86ac96936cd7ff09e25f18ae6b758e8014a24c7fa039e91</td>
#       <td>13.344878</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NOINFORMACION</td>
#       <td>10.254223</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>182b798959e66ad76aad092ee2199146d3ef281b7ec7b3f8807faf15adb1d19c</td>
#       <td>2.393958</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c8f81211f4fd423797d2a61e3ae1ca32853fc979cc355236039abbba5a15fc3b</td>
#       <td>2.392127</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>f62c0463a971774b09a36a703590df43dcebd261d0da8fedd05b92c017004a35</td>
# ...
